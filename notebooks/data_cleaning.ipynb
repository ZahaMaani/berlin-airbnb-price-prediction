# %%
import pandas as pd
import sys
import os

# Add the parent directory to path so we can import from 'src'
sys.path.append(os.path.abspath('..'))

from src.data_preprocessing import AirbnbPreprocessor

# %%
df = pd.read_csv('../data/listings.csv')

# %%
processor = AirbnbPreprocessor()

# Learn medians from this specific dataset
processor.fit(df)
# Out:
# Training complete.

# %%
df_clean = processor.transform(df)

# Check the result
print(df_clean.info())
df_clean.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14274 entries, 0 to 14273
# Data columns (total 40 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host_response_time                            14274 non-null  object
#  1   host_response_rate                            14274 non-null  float64
#  2   host_acceptance_rate                          14274 non-null  float64
#  3   host_listings_count                           14274 non-null  float64
#  4   host_identity_verified                        14274 non-null  bool
#  5   neighbourhood_cleansed                        14274 non-null  object
#  6   neighbourhood_group_cleansed                  14274 non-null  object
#  7   property_type                                 14274 non-null  object
#  8   room_type                                     14274 non-null  object
# ...

# %%
# 1. Save the clean data for training the model
df_clean.to_csv('../data/listings_processed.csv', index=False)

# 2. Save the BRAIN (the preprocessor)
os.makedirs('../models', exist_ok=True)
processor.save_preprocessor('../models/preprocessor.pkl')

print("Data and Preprocessor saved successfully.")
# Out:
# Data and Preprocessor saved successfully.
